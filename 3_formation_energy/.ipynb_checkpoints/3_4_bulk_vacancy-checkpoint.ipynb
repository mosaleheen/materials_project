# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('../final_metal_oxide_properties.xlsx', sheet_name='oxide_correlation')

# %%
df.drop(columns=['t_peak_1','t_peak_2','t_peak_3','Unnamed: 9','select_oxides','vacancy_form_energy(eV)'], inplace=True)

# %%
df.head()
# Out:
#   unique_oxides  formation__energy_per_oxygen_ev  t_onset  t_max  t_melt  \
# 0         Ac2O3                        -8.720482      NaN    NaN  1977.0
# 1           AgO                        -3.385787      NaN    NaN   100.0
# 2         Ag3O4                        -3.200600      NaN    NaN     NaN
# 3          Ag2O                        -3.456287     60.0  191.3   200.0
# 4         Al2O3                        -8.204621      NaN    NaN  2053.0
#
#    e_bulk_vacancy
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
df = df[np.isfinite(df['e_bulk_vacancy'])]

# %%
df
# Out:
#     unique_oxides  formation__energy_per_oxygen_ev  t_onset  t_max  t_melt  \
# 15          Bi2O3                        -5.223821    277.0  477.0   817.0
# 17            CdO                        -5.232587     95.0   95.0  1430.0
# 26          Co3O4                        -4.947737      NaN    NaN   900.0
# 27            CoO                        -5.127887    364.0  364.0  1830.0
# 43          Fe2O3                        -5.611396    325.0  600.0  1565.0
# 44          Fe3O4                        -5.687887    300.0  750.0  1597.0
# 45            FeO                        -5.824987    380.0  550.0  1377.0
# 48           GeO2                        -5.608712    327.0  327.0  1115.0
# 65          Mn3O4                        -6.078776      NaN    NaN  1567.0
# 66          Mn2O3                        -5.847803      NaN    NaN  1080.0
# 67            MnO                        -6.468689      NaN    NaN  1839.0
# 69           MoO3                        -5.162121    327.0  577.0   801.0
# 70           MoO2                        -5.693050    557.0  612.0  1100.0
# 87          Pb3O4                        -5.024456      NaN    NaN   830.0
# 88            PbO                        -5.430606    200.0  200.0   897.0
# 107          SbO2                        -5.249456      NaN    NaN     NaN
# 108         Sb2O3                        -5.412054    550.0  550.0   656.0
# 114         Sn5O6                        -5.725521      NaN    NaN     NaN
# 115          SnO2                        -5.655037    500.0  500.0  1630.0
# 116           SnO                        -5.756137      NaN    NaN  1080.0
# 125          TeO2                        -4.731762      NaN    NaN   733.0
# 141          V3O7                        -5.856173      NaN    NaN     NaN
# 142          V3O5                        -6.501247      NaN    NaN     NaN
# 143          V2O5                        -5.689377      NaN    NaN   670.0
# 147           WO3                        -5.379437      NaN    NaN  1472.0
# 148           WO2                        -5.515800      NaN    NaN  1500.0
#
#      e_bulk_vacancy
# 15         3.037326
# 17         3.151560
# 26         2.120717
# 27         3.880520
# 43         3.420714
# 44         2.723768
# 45         4.374594
# 48         3.162779
# 65         2.748027
# 66         2.180772
# 67         4.788915
# 69         3.066800
# 70         4.811586
# 87         2.264500
# 88         2.962364
# 107        2.320317
# 108        3.315865
# 114        3.817819
# 115        3.264642
# 116        3.253356
# 125        2.703030
# 141        2.231413
# 142        4.608182
# 143        1.455985
# 147        4.474074
# 148        5.411945

# %%
#sns.set_style('darkgrid')

# %%
sns.scatterplot(x='formation__energy_per_oxygen_ev', y='e_bulk_vacancy', data=df)

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import rcParams
from adjustText import adjust_text
rcParams['axes.titlepad'] = 15
plt.rcParams.update({'font.size': 18})
x = list(df['formation__energy_per_oxygen_ev'])
y = list(df['e_bulk_vacancy'])
label = list(df['unique_oxides'])
plt.figure(figsize=(20,15))
plt.scatter(x, y, s=100, color='green')
plt.title('vacancy formation energy vs formation energy per oxygen atom')
plt.xlabel('Standard gibbs free energy of oxide formation per O atom(eV)')
plt.ylabel('Bulk vacancy formation energy(eV)')
#plt.axhline(y=500, color='red', linestyle='--') 
#plt.axvline(x=-4.7, color='red', linestyle='--') 
#plt.axvline(x=-6.2, color='red', linestyle='--') 
for i, label in enumerate(label):
    plt.annotate(label, (x[i], y[i]), textcoords='offset points', xytext=(0,10), ha='center')
