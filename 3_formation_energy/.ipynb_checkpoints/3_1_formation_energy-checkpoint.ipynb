# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('formation_energy.xlsx')
df.head()
# Out:
#   unique_oxides  formation__energy_per_oxygen_ev  t_onset t_peak_1 t_peak_2  \
# 0         Ac2O3                        -8.720482      NaN      NaN      NaN
# 1           AgO                        -3.385787      NaN      NaN      NaN
# 2         Ag3O4                        -3.200600      NaN      NaN      NaN
# 3          Ag2O                        -3.456287     60.0    112.5    191.3
# 4         Al2O3                        -8.204621      NaN      NaN      NaN
#
#   t_peak_3  t_max
# 0      NaN    NaN
# 1      NaN    NaN
# 2      NaN    NaN
# 3        -  191.3
# 4      NaN    NaN

# %%
df = df[np.isfinite(df['t_max'])]
df.head()
# Out:
#    unique_oxides  formation__energy_per_oxygen_ev  t_onset t_peak_1 t_peak_2  \
# 3           Ag2O                        -3.456287     60.0    112.5    191.3
# 15         Bi2O3                        -5.223821    277.0      477        -
# 17           CdO                        -5.232587     95.0        -        -
# 19          CeO2                        -8.385387    327.0      527      827
# 27           CoO                        -5.127887    364.0        -        -
#
#    t_peak_3  t_max
# 3         -  191.3
# 15        -  477.0
# 17        -   95.0
# 19        -  827.0
# 27        -  364.0

# %%
import matplotlib.pyplot as plt
plt.scatter(df['formation__energy_per_oxygen_ev'], df['t_onset'], color= 'red', marker='+')

# %%
plt.scatter(df['formation__energy_per_oxygen_ev'], df['t_max'], color= 'red', marker='+')

# %%
df
# Out:
#     unique_oxides  formation__energy_per_oxygen_ev  t_onset t_peak_1 t_peak_2  \
# 3            Ag2O                        -3.456287     60.0    112.5    191.3
# 15          Bi2O3                        -5.223821    277.0      477        -
# 17            CdO                        -5.232587     95.0        -        -
# 19           CeO2                        -8.385387    327.0      527      827
# 27            CoO                        -5.127887    364.0        -        -
# 30          Cr2O3                        -6.383721    197.0      275        -
# 36            CuO                        -4.374537    280.0      244        -
# 38           Cu2O                        -4.415487    200.0      255        -
# 43          Fe2O3                        -5.611396    325.0      400      600
# 44          Fe3O4                        -5.687887    300.0      325      650
# 45            FeO                        -5.824987    380.0      550        -
# 46          Ga2O3                        -6.269204   1000.0        -        -
# 48           GeO2                        -5.608712    327.0        -        -
# 64           MnO2                        -5.183313    200.0        -        -
# 69           MoO3                        -5.162121    327.0      377      527
# 70           MoO2                        -5.693050    557.0      612        -
# 74          Nb2O5                        -6.792707    900.0        -        -
# 79            NiO                        -4.332287    285.0      315        -
# 88            PbO                        -5.430606    200.0        -        -
# 108         Sb2O3                        -5.412054    550.0        -        -
# 115          SnO2                        -5.655037    500.0        -        -
#
#     t_peak_3   t_max
# 3          -   191.3
# 15         -   477.0
# 17         -    95.0
# 19         -   827.0
# 27         -   364.0
# 30         -   275.0
# 36         -   280.0
# 38         -   255.0
# 43         -   600.0
# 44       750   750.0
# 45         -   550.0
# 46         -  1000.0
# 48         -   327.0
# 64         -   200.0
# 69       577   577.0
# 70         -   612.0
# 74         -   900.0
# 79         -   315.0
# 88         -   200.0
# 108        -   550.0
# 115        -   500.0

# %%
x = df['formation__energy_per_oxygen_ev']
y_onset = df['t_onset']
y_peak = df['t_max']
plt.scatter(x, y_onset)

# %%
df
# Out:
#     unique_oxides  formation__energy_per_oxygen_ev  t_onset t_peak_1 t_peak_2  \
# 3            Ag2O                        -3.456287     60.0    112.5    191.3
# 15          Bi2O3                        -5.223821    277.0      477        -
# 17            CdO                        -5.232587     95.0        -        -
# 19           CeO2                        -8.385387    327.0      527      827
# 27            CoO                        -5.127887    364.0        -        -
# 30          Cr2O3                        -6.383721    197.0      275        -
# 36            CuO                        -4.374537    280.0      244        -
# 38           Cu2O                        -4.415487    200.0      255        -
# 43          Fe2O3                        -5.611396    325.0      400      600
# 44          Fe3O4                        -5.687887    300.0      325      650
# 45            FeO                        -5.824987    380.0      550        -
# 46          Ga2O3                        -6.269204   1000.0        -        -
# 48           GeO2                        -5.608712    327.0        -        -
# 64           MnO2                        -5.183313    200.0        -        -
# 69           MoO3                        -5.162121    327.0      377      527
# 70           MoO2                        -5.693050    557.0      612        -
# 74          Nb2O5                        -6.792707    900.0        -        -
# 79            NiO                        -4.332287    285.0      315        -
# 88            PbO                        -5.430606    200.0        -        -
# 108         Sb2O3                        -5.412054    550.0        -        -
# 115          SnO2                        -5.655037    500.0        -        -
#
#     t_peak_3   t_max
# 3          -   191.3
# 15         -   477.0
# 17         -    95.0
# 19         -   827.0
# 27         -   364.0
# 30         -   275.0
# 36         -   280.0
# 38         -   255.0
# 43         -   600.0
# 44       750   750.0
# 45         -   550.0
# 46         -  1000.0
# 48         -   327.0
# 64         -   200.0
# 69       577   577.0
# 70         -   612.0
# 74         -   900.0
# 79         -   315.0
# 88         -   200.0
# 108        -   550.0
# 115        -   500.0

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import rcParams
from adjustText import adjust_text
rcParams['axes.titlepad'] = 15
plt.rcParams.update({'font.size': 18})
x = list(df['formation__energy_per_oxygen_ev'])
y_onset = list(df['t_onset'])
y_peak = list(df['t_max'])
label = list(df['unique_oxides'])
plt.figure(figsize=(20,15))
plt.scatter(x, y_onset, s=100)
plt.title('Formation energy vs onset reduction temperature')
plt.xlabel('Standard gibbs free energy of oxide formation per O atom(eV)')
plt.ylabel('Onset reduction temperature($^\circ$C)')
 
for i, label in enumerate(label):
    plt.annotate(label, (x[i], y_onset[i]), textcoords='offset points', xytext=(0,10), ha='center')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams['axes.titlepad'] = 15
plt.rcParams.update({'font.size': 18})
x = list(df['formation__energy_per_oxygen_ev'])
y_onset = list(df['t_onset'])
y_peak = list(df['t_max'])
label = list(df['unique_oxides'])
plt.figure(figsize=(20,15))
plt.scatter(x, y_peak, color='red', s =100)
plt.title('Formation energy vs peak reduction temperature')
plt.xlabel('Standard gibbs free energy of oxide formation per O atom(eV)')
plt.ylabel('Peak reduction temperature($^\circ$C)')
 
for i, label in enumerate(label):
     plt.annotate(label, (x[i], y_peak[i]), textcoords='offset points', xytext=(0.0,10), ha='center')
