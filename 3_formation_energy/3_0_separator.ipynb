# %%
import re
oxides = ['Ac2O3','AgO','Ag3O4','Ag2O','Al2O3','As2O5','As2O3','Au2O3','B2O3','B6O','BaO2','BaO','BeO','Bi4O7','BiO2',
          'Bi2O3','CaO','CdO','Ce17O32','CeO2','Ce11O20','Ce5O9','Ce2O3','Ce7O12','CeO','CoO2','Co3O4','CoO','Cr5O12',
          'CrO2','Cr2O3','Cs2O2','Cs2O','CsO2','Cs3O','Cs11O3','CuO','Cu2O3','Cu2O','Dy2O3','Er2O3','Eu2O3','EuO','Fe2O3',
          'Fe3O4','FeO','Ga2O3','Gd2O3','GeO2','HfO2','HgO','Ho2O3','I2O5','In2O3','IrO3','IrO2','KO2','K2O2','K2O','La2O3',
          'Li2O2','Li2O','Lu2O3','MgO','MnO2','Mn3O4','Mn2O3','MnO','Mo8O23','MoO3','MoO2','Na2O2','NaO2','Na2O','Nb2O5',
          'NbO2','NbO','Nd2O3','Ni3O4','NiO','NpO2','OsO4','OsO2','P2O5','PaO3','PaO2','PbO2','Pb3O4','PbO','PdO2','PdO',
          'Pm2O3','Pr2O3','PtO2','Pt3O4','PuO2','Pu2O3','Rb2O2','RbO2','Rb2O','Rb9O2','Re2O7','ReO3','RhO2','RuO4','RuO2',
          'Sb2O5','SbO2','Sb2O3','Sc2O3','Se2O5','SeO2','SiO2','Sm2O3','Sn5O6','SnO2','SnO','SrO2','SrO','Ta2O5','Tb2O3',
          'Tc2O7','TcO2','Te2O5','TeO3','TeO2','ThO2','TiO2','TiO','Ti2O','Ti3O','Ti3O5','Ti2O3','Ti6O','Tl4O3','Tl2O3',
          'Tl2O','Tm2O3','UO3','U3O8','UO2','V3O7','V3O5','V2O5','VO2','V2O3','W18O49','WO3','WO2','Y2O3','YbO','ZnO','ZrO2',
          'Zr3O']

# %%
for oxide in oxides:
    print(re.split('(\d+)',oxide))
# Out:
# ['Ac', '2', 'O', '3', '']
# ['AgO']
# ['Ag', '3', 'O', '4', '']
# ['Ag', '2', 'O']
# ['Al', '2', 'O', '3', '']
# ['As', '2', 'O', '5', '']
# ['As', '2', 'O', '3', '']
# ['Au', '2', 'O', '3', '']
# ['B', '2', 'O', '3', '']
# ['B', '6', 'O']
# ['BaO', '2', '']
# ['BaO']
# ['BeO']
# ['Bi', '4', 'O', '7', '']
# ['BiO', '2', '']
# ['Bi', '2', 'O', '3', '']
# ['CaO']
# ['CdO']
# ['Ce', '17', 'O', '32', '']
# ['CeO', '2', '']
# ['Ce', '11', 'O', '20', '']
# ['Ce', '5', 'O', '9', '']
# ['Ce', '2', 'O', '3', '']
# ['Ce', '7', 'O', '12', '']
# ['CeO']
# ['CoO', '2', '']
# ['Co', '3', 'O', '4', '']
# ['CoO']
# ['Cr', '5', 'O', '12', '']
# ['CrO', '2', '']
# ['Cr', '2', 'O', '3', '']
# ['Cs', '2', 'O', '2', '']
# ['Cs', '2', 'O']
# ['CsO', '2', '']
# ['Cs', '3', 'O']
# ['Cs', '11', 'O', '3', '']
# ['CuO']
# ['Cu', '2', 'O', '3', '']
# ['Cu', '2', 'O']
# ['Dy', '2', 'O', '3', '']
# ['Er', '2', 'O', '3', '']
# ['Eu', '2', 'O', '3', '']
# ['EuO']
# ['Fe', '2', 'O', '3', '']
# ...
