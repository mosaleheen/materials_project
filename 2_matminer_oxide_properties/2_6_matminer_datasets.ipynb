# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
from matminer.datasets import load_dataset

# %%
df = load_dataset('elastic_tensor_2015')
# Out:
# Fetching elastic_tensor_2015.json.gz from https://ndownloader.figshare.com/files/13220603 to C:\Users\saleheen\AppData\Roaming\Python\Python37\site-packages\matminer\datasets\elastic_tensor_2015.json.gz
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning:
#
# numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning:
#
# numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject

# %%
df.head()
# Out:
#   material_id    formula  nsites  space_group      volume  \
# 0    mp-10003    Nb4CoSi      12          124  194.419802
# 1    mp-10010  Al(CoSi)2       5          164   61.987320
# 2    mp-10015       SiOs       2          221   25.952539
# 3    mp-10021         Ga       4           63   76.721433
# 4    mp-10025      SiRu2      12           62  160.300999
#
#                                            structure  elastic_anisotropy  \
# 0  [[0.94814328 2.07280467 2.5112    ] Nb, [5.273...            0.030688
# 1  [[0. 0. 0.] Al, [1.96639263 1.13529553 0.75278...            0.266910
# 2   [[1.480346 1.480346 1.480346] Si, [0. 0. 0.] Os]            0.756489
# 3  [[0.         1.09045794 0.84078375] Ga, [0.   ...            2.376805
# 4  [[1.0094265  4.24771709 2.9955487 ] Si, [3.028...            0.196930
#
#       G_Reuss       G_VRH     G_Voigt     K_Reuss       K_VRH     K_Voigt  \
# 0   96.844535   97.141604   97.438674  194.267623  194.268884  194.270146
# ...

# %%
df[df['formula'].str.contains('Zr') & df['formula'].str.contains('O')]
# Out:
#     material_id formula  nsites  space_group      volume  \
# 680     mp-2858    ZrO2      12           14  146.804271
# 847     mp-4820  ZrSiO4      24          141  271.429247
#
#                                              structure  elastic_anisotropy  \
# 680  [[3.73578755 5.04892223 3.62223818] Zr, [3.726...            0.451078
# 847  [[0.         5.02820475 0.7548545 ] Zr, [0.   ...            1.017760
#
#        G_Reuss      G_VRH     G_Voigt     K_Reuss       K_VRH     K_Voigt  \
# 680  81.466701  84.641950   87.817199  177.606128  183.051286  188.496445
# 847  87.158203  95.727453  104.296703  200.041116  203.499523  206.957930
#
#      poisson_ratio                                  compliance_tensor  \
# 680       0.299679  [[0.005158865715388, -0.001624439240336, -0.00...
# 847       0.296678  [[0.0030700322680680004, -0.000103945000394000...
#
#                                         elastic_tensor  \
# 680  [[255.55564332559783, 139.86700165857192, 99.3...
# ...

# %%
df = load_dataset('brgoch_superhard_training')
# Out:
# Fetching brgoch_superhard_training.json.gz from https://ndownloader.figshare.com/files/13858931 to C:\Users\saleheen\AppData\Roaming\Python\Python37\site-packages\matminer\datasets\brgoch_superhard_training.json.gz

# %%
df[df['formula'].str.contains('Rb') & df['formula'].str.contains('O')][['formula','shear_modulus', 'bulk_modulus']]
# Out:
#        formula  shear_modulus  bulk_modulus
# 1906    RbScO2      55.381449     95.006523
# 2172    RbScO2      57.962280     95.084251
# 2340  Rb2Sn2O3      18.257051     24.066288

# %%
oxides= ['Ag3O4','AgO','Ce11O20','Ce17O32','Ce2O3','Ce5O9','Ce7O12','Co3O4','CrO2','Cs11O3','Cs2O2','Cs3O','Eu2O3','EuO',
         'FeO','I2O5','IrO3','La2O3','Lu2O3','MnO2','Mo8O23','NaO2','Nb2O5','NbO','NpO2','PbO','PbO2','PdO2','Pm2O3','Pr2O3',
         'Pu2O3','Rb2O2','Rb9O2','Re2O7','RuO4','Se2O5','SeO2','Sn5O6','Tc2O7','Ti3O','Ti6O','Tl2O','Tl4O3','Tm2O3','U3O8',
         'V2O3','V2O5','V3O7','W18O49']
for oxide in oxides:
    print(df[df['formula'] == oxide][['formula','shear_modulus', 'bulk_modulus']])
# Out:
# Empty DataFrame
# Columns: [formula, shear_modulus, bulk_modulus]
# Index: []
# Empty DataFrame
# Columns: [formula, shear_modulus, bulk_modulus]
# Index: []
# Empty DataFrame
# Columns: [formula, shear_modulus, bulk_modulus]
# Index: []
# Empty DataFrame
# Columns: [formula, shear_modulus, bulk_modulus]
# Index: []
# Empty DataFrame
# Columns: [formula, shear_modulus, bulk_modulus]
# Index: []
# Empty DataFrame
# Columns: [formula, shear_modulus, bulk_modulus]
# Index: []
# Empty DataFrame
# Columns: [formula, shear_modulus, bulk_modulus]
# Index: []
# Empty DataFrame
# Columns: [formula, shear_modulus, bulk_modulus]
# Index: []
#    formula  shear_modulus  bulk_modulus
# 38    CrO2      100.80716    196.620985
# Empty DataFrame
# Columns: [formula, shear_modulus, bulk_modulus]
# Index: []
# Empty DataFrame
# Columns: [formula, shear_modulus, bulk_modulus]
# Index: []
# Empty DataFrame
# Columns: [formula, shear_modulus, bulk_modulus]
# Index: []
# Empty DataFrame
# ...

# %%
df = load_dataset('elastic_tensor_2015')

# %%
df.head()
# Out:
#   material_id    formula  nsites  space_group      volume  \
# 0    mp-10003    Nb4CoSi      12          124  194.419802
# 1    mp-10010  Al(CoSi)2       5          164   61.987320
# 2    mp-10015       SiOs       2          221   25.952539
# 3    mp-10021         Ga       4           63   76.721433
# 4    mp-10025      SiRu2      12           62  160.300999
#
#                                            structure  elastic_anisotropy  \
# 0  [[0.94814328 2.07280467 2.5112    ] Nb, [5.273...            0.030688
# 1  [[0. 0. 0.] Al, [1.96639263 1.13529553 0.75278...            0.266910
# 2   [[1.480346 1.480346 1.480346] Si, [0. 0. 0.] Os]            0.756489
# 3  [[0.         1.09045794 0.84078375] Ga, [0.   ...            2.376805
# 4  [[1.0094265  4.24771709 2.9955487 ] Si, [3.028...            0.196930
#
#       G_Reuss       G_VRH     G_Voigt     K_Reuss       K_VRH     K_Voigt  \
# 0   96.844535   97.141604   97.438674  194.267623  194.268884  194.270146
# ...
