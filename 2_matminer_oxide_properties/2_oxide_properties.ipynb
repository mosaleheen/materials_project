# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matminer.data_retrieval.retrieve_Citrine import CitrineDataRetrieval
from pymatgen.ext.matproj import MPRester

# %%
api_key = 'Id6azt1PYxWaioYsjJyi9Qtt'
citrine = CitrineDataRetrieval(api_key)
mp_key = '3ZvdRbGJX2dwZIaljnX'
mp = MPRester(mp_key)

# %%
df = pd.read_excel('../final_metal_oxide_properties.xlsx', sheet_name='oxide_properties')

# %%
df.drop(columns=['Index'], inplace=True)

# %%
df.head()
# Out:
#             Data Dictionary Oxidized Form   HOMO   LUMO     BC   OxM     CE  \
# 0                 HOMO (eV)         Ac2O3    NaN    NaN    NaN  3.00    NaN
# 1                 LUMO (eV)          Ag2O    NaN    NaN    NaN  1.00    NaN
# 2           Band center, BC         Ag3O4    NaN    NaN    NaN  2.67    NaN
# 3      Oxidation state, OxS           AgO -0.299 -0.299 -2.577  2.00  3.229
# 4  Cohesive energy, CE (eV)         As2O3    NaN    NaN    NaN  3.00    NaN
#
#   Shear Bulk    BG  ...  CNM  CNO   NNDr   NNDa    BV     ρ     Vol     PF  \
# 0    35  103  3.52  ...  NaN  NaN    NaN    NaN   NaN  8.97   92.88    NaN
# 1     0   68     0  ...  NaN  NaN    NaN    NaN   NaN  6.78  113.44    NaN
# 2     0    0     0  ...  NaN  NaN    NaN    NaN   NaN  6.55  196.38    NaN
# 3    10  113     0  ...  4.0  4.0  0.802  2.165  1.67  6.75   60.92  0.595
# 4     8   10  3.62  ...  NaN  NaN    NaN    NaN   NaN  3.47  378.97    NaN
#
#     SG  SGT
# 0  164  NaN
# 1  224  NaN
# 2   14  NaN
# 3   66  5.0
# 4   14  NaN
#
# [5 rows x 22 columns]

# %%
# from pymatgen.core.structure import Structure
# from pymatgen.core.composition import Composition
# from matminer.featurizers.conversions import Composition
# from matminer.featurizers.composition import AtomicOrbitals
# from matminer.featurizers.composition import BandCenter
# from matminer.featurizers.composition import OxidationStates
# from matminer.featurizers.conversions import StructureToOxidStructure 
# # utility featurizer to add oxidation states to a pymatgen structure
# from matminer.featurizers.conversions import CompositionToOxidComposition
# # utility featurizer to add oxidation states to a pymatgen Composition
import pymatgen as pm
from pymatgen.core.structure import Structure
from pymatgen.core.composition import Composition
from matminer.featurizers.conversions import *
from matminer.featurizers.composition import *
from matminer.featurizers.structure import *
from matminer.featurizers.site import *

# %%
# excluded oxides : 'NpO2','Pu2O3','PuO2'
oxides = ['Ac2O3','Ag2O','Ag3O4','AgO','As2O3','As2O5','Au2O3','B2O3','B6O','BaO','BaO2','BeO','Bi2O3','Bi4O7','BiO2',
          'CaO','CdO','Ce11O20','Ce17O32','Ce2O3','Ce5O9','Ce7O12','CeO','CeO2','Co3O4','CoO','CoO2','Cr2O3','Cr5O12',
          'CrO2','Cs11O3','Cs2O','Cs2O2','Cs3O','CsO2','Cu2O','Cu2O3','CuO','Dy2O3','Er2O3','Eu2O3','EuO','Fe2O3',
          'Fe3O4','FeO','Ga2O3','Gd2O3','GeO2','HfO2','HgO','Ho2O3','I2O5','In2O3','IrO2','IrO3','K2O','K2O2','KO2',
          'La2O3','Li2O','Li2O2','Lu2O3','MgO','Mn2O3','Mn3O4','MnO','MnO2','Mo8O23','MoO2','MoO3','Na2O','Na2O2',
          'NaO2','Nb2O5','NbO','NbO2','Nd2O3','Ni3O4','NiO','OsO2','OsO4','P2O5','PaO2','PaO3','Pb3O4','PbO',
          'PbO2','PdO','PdO2','Pm2O3','Pr2O3','Pt3O4','PtO2','Rb2O','Rb2O2','Rb9O2','RbO2','Re2O7',
          'ReO3','RhO2','RuO2','RuO4','Sb2O3','Sb2O5','SbO2','Sc2O3','Se2O5','SeO2','SiO2','Sm2O3','Sn5O6','SnO',
          'SnO2','SrO','SrO2','Ta2O5','Tb2O3','Tc2O7','TcO2','Te2O5','TeO2','TeO3','ThO2','Ti2O','Ti2O3','Ti3O',
          'Ti3O5','Ti6O','TiO','TiO2','Tl2O','Tl2O3','Tl4O3','Tm2O3','U3O8','UO2','UO3','V2O3','V2O5','V3O5','V3O7',
          'VO2','W18O49','WO2','WO3','Y2O3','YbO','ZnO','Zr3O','ZrO2']
print('{}\t{}\t{}\t{}'.format('oxides','homo','lumo','gap'))
for oxide in oxides:
    comp_oxide = Composition(oxide)
    orbitals = AtomicOrbitals().featurize(comp_oxide)
    print('{}\t{:6.3f}\t{:6.3f}\t{:6.3f}'.format(oxide, orbitals[2], orbitals[5], orbitals[6]))

## use AtomicOrbitals().featurize_dataframe(df, 'Oxidized Form') to do this job
# Out:
# oxides	homo	lumo	gap
# Ac2O3	-0.338	-0.138	 0.201
# Ag2O	-0.299	-0.157	 0.141
# Ag3O4	-0.299	-0.299	 0.000
# AgO	-0.299	-0.299	 0.000
# As2O3	-0.338	-0.197	 0.141
# As2O5	-0.338	-0.338	 0.000
# Au2O3	-0.305	-0.305	 0.000
# B2O3	-0.338	-0.338	 0.000
# B6O	-0.137	-0.137	 0.000
# BaO	-0.338	-0.119	 0.219
# BaO2	-0.338	-0.338	 0.000
# BeO	-0.338	-0.206	 0.133
# Bi2O3	-0.338	-0.180	 0.158
# Bi4O7	-0.338	-0.338	 0.000
# BiO2	-0.338	-0.338	 0.000
# CaO	-0.338	-0.141	 0.197
# CdO	-0.338	-0.204	 0.134
# Ce11O20	-0.337	-0.337	 0.000
# Ce17O32	-0.337	-0.337	 0.000
# Ce2O3	-0.337	-0.337	 0.000
# Ce5O9	-0.337	-0.337	 0.000
# Ce7O12	-0.337	-0.337	 0.000
# CeO	-0.337	-0.337	 0.000
# CeO2	-0.338	-0.337	 0.001
# Co3O4	-0.322	-0.322	 0.000
# CoO	-0.322	-0.322	 0.000
# CoO2	-0.322	-0.322	 0.000
# Cr2O3	-0.118	-0.118	 0.000
# Cr5O12	-0.150	-0.150	 0.000
# CrO2	-0.150	-0.118	 0.032
# Cs11O3	-0.079	-0.079	 0.000
# Cs2O	-0.338	-0.079	 0.260
# Cs2O2	-0.338	-0.338	 0.000
# Cs3O	-0.079	-0.079	 0.000
# CsO2	-0.338	-0.338	 0.000
# Cu2O	-0.202	-0.172	 0.030
# Cu2O3	-0.202	-0.202	 0.000
# CuO	-0.202	-0.202	 0.000
# Dy2O3	-0.265	-0.265	 0.000
# Er2O3	-0.279	-0.279	 0.000
# Eu2O3	-0.233	-0.233	 0.000
# EuO	-0.233	-0.233	 0.000
# Fe2O3	-0.295	-0.295	 0.000
# Fe3O4	-0.295	-0.295	 0.000
# FeO	-0.295	-0.295	 0.000
# Ga2O3	-0.338	-0.328	 0.010
# Gd2O3	-0.338	-0.338	 0.000
# GeO2	-0.338	-0.338	 0.000
# HfO2	-0.338	-0.166	 0.172
# HgO	-0.338	-0.205	 0.133
# Ho2O3	-0.273	-0.273	 0.000
# I2O5	-0.338	-0.268	 0.070
# In2O3	-0.338	-0.290	 0.048
# IrO2	-0.335	-0.335	 0.000
# IrO3	-0.335	-0.335	 0.000
# K2O	-0.338	-0.089	 0.250
# K2O2	-0.338	-0.338	 0.000
# KO2	-0.338	-0.338	 0.000
# La2O3	-0.338	-0.141	 0.197
# Li2O	-0.338	-0.106	 0.233
# Li2O2	-0.338	-0.338	 0.000
# Lu2O3	-0.338	-0.155	 0.183
# MgO	-0.338	-0.175	 0.163
# Mn2O3	-0.267	-0.267	 0.000
# Mn3O4	-0.267	-0.267	 0.000
# MnO	-0.267	-0.267	 0.000
# MnO2	-0.267	-0.267	 0.000
# Mo8O23	-0.153	-0.153	 0.000
# MoO2	-0.153	-0.153	 0.000
# MoO3	-0.338	-0.153	 0.185
# Na2O	-0.338	-0.103	 0.235
# Na2O2	-0.338	-0.338	 0.000
# NaO2	-0.338	-0.338	 0.000
# Nb2O5	-0.338	-0.144	 0.194
# NbO	-0.125	-0.125	 0.000
# NbO2	-0.144	-0.144	 0.000
# Nd2O3	-0.180	-0.180	 0.000
# Ni3O4	-0.338	-0.338	 0.000
# NiO	-0.338	-0.338	 0.000
# OsO2	-0.297	-0.297	 0.000
# OsO4	-0.338	-0.297	 0.042
# P2O5	-0.338	-0.338	 0.000
# PaO2	-0.317	-0.317	 0.000
# PaO3	-0.338	-0.338	 0.000
# Pb3O4	-0.338	-0.338	 0.000
# PbO	-0.338	-0.142	 0.197
# PbO2	-0.338	-0.338	 0.000
# PdO	-0.161	-0.161	 0.000
# PdO2	-0.161	-0.161	 0.000
# Pm2O3	-0.200	-0.200	 0.000
# Pr2O3	-0.155	-0.155	 0.000
# Pt3O4	-0.274	-0.274	 0.000
# PtO2	-0.274	-0.274	 0.000
# Rb2O	-0.338	-0.085	 0.253
# Rb2O2	-0.338	-0.338	 0.000
# Rb9O2	-0.085	-0.085	 0.000
# RbO2	-0.338	-0.338	 0.000
# Re2O7	-0.338	-0.259	 0.080
# ReO3	-0.259	-0.259	 0.000
# RhO2	-0.239	-0.239	 0.000
# RuO2	-0.210	-0.210	 0.000
# RuO4	-0.338	-0.210	 0.128
# Sb2O3	-0.338	-0.186	 0.153
# Sb2O5	-0.338	-0.338	 0.000
# SbO2	-0.338	-0.338	 0.000
# Sc2O3	-0.338	-0.156	 0.182
# Se2O5	-0.338	-0.338	 0.000
# SeO2	-0.338	-0.246	 0.093
# SiO2	-0.338	-0.338	 0.000
# Sm2O3	-0.218	-0.218	 0.000
# Sn5O6	-0.338	-0.338	 0.000
# SnO	-0.338	-0.144	 0.194
# SnO2	-0.338	-0.338	 0.000
# SrO	-0.338	-0.132	 0.207
# SrO2	-0.338	-0.338	 0.000
# Ta2O5	-0.338	-0.182	 0.156
# Tb2O3	-0.256	-0.256	 0.000
# Tc2O7	-0.338	-0.270	 0.068
# TcO2	-0.270	-0.270	 0.000
# Te2O5	-0.338	-0.338	 0.000
# TeO2	-0.338	-0.227	 0.112
# TeO3	-0.338	-0.338	 0.000
# ThO2	-0.338	-0.173	 0.165
# Ti2O	-0.170	-0.170	 0.000
# Ti2O3	-0.170	-0.170	 0.000
# Ti3O	-0.170	-0.170	 0.000
# Ti3O5	-0.170	-0.170	 0.000
# Ti6O	-0.170	-0.170	 0.000
# TiO	-0.170	-0.170	 0.000
# TiO2	-0.338	-0.170	 0.168
# Tl2O	-0.285	-0.102	 0.184
# Tl2O3	-0.338	-0.285	 0.053
# Tl4O3	-0.285	-0.285	 0.000
# Tm2O3	-0.283	-0.283	 0.000
# U3O8	-0.338	-0.338	 0.000
# UO2	-0.367	-0.338	 0.028
# UO3	-0.338	-0.338	 0.000
# V2O3	-0.205	-0.205	 0.000
# V2O5	-0.338	-0.205	 0.134
# V3O5	-0.205	-0.205	 0.000
# V3O7	-0.205	-0.205	 0.000
# VO2	-0.205	-0.205	 0.000
# W18O49	-0.221	-0.221	 0.000
# WO2	-0.221	-0.221	 0.000
# WO3	-0.338	-0.221	 0.118
# Y2O3	-0.338	-0.151	 0.188
# YbO	-0.286	-0.137	 0.149
# ZnO	-0.338	-0.223	 0.116
# Zr3O	-0.151	-0.151	 0.000
# ZrO2	-0.338	-0.162	 0.176

# %%
# excluded oxides : 'PaO2','PaO3','Pm2O3'
oxides = ['Ac2O3','Ag2O','Ag3O4','AgO','As2O3','As2O5','Au2O3','B2O3','B6O','BaO','BaO2','BeO','Bi2O3','Bi4O7',
          'BiO2','CaO','CdO','Ce11O20','Ce17O32','Ce2O3','Ce5O9','Ce7O12','CeO','CeO2','Co3O4','CoO','CoO2','Cr2O3',
          'Cr5O12','CrO2','Cs11O3','Cs2O','Cs2O2','Cs3O','CsO2','Cu2O','Cu2O3','CuO','Dy2O3','Er2O3','Eu2O3','EuO',
          'Fe2O3','Fe3O4','FeO','Ga2O3','Gd2O3','GeO2','HfO2','HgO','Ho2O3','I2O5','In2O3','IrO2','IrO3','K2O','K2O2',
          'KO2','La2O3','Li2O','Li2O2','Lu2O3','MgO','Mn2O3','Mn3O4','MnO','MnO2','Mo8O23','MoO2','MoO3','Na2O','Na2O2',
          'NaO2','Nb2O5','NbO','NbO2','Nd2O3','Ni3O4','NiO','NpO2','OsO2','OsO4','P2O5','Pb3O4','PbO','PbO2',
          'PdO','PdO2','Pr2O3','Pt3O4','PtO2','Pu2O3','PuO2','Rb2O','Rb2O2','Rb9O2','RbO2','Re2O7','ReO3','RhO2','RuO2',
          'RuO4','Sb2O3','Sb2O5','SbO2','Sc2O3','Se2O5','SeO2','SiO2','Sm2O3','Sn5O6','SnO','SnO2','SrO','SrO2','Ta2O5',
          'Tb2O3','Tc2O7','TcO2','Te2O5','TeO2','TeO3','ThO2','Ti2O','Ti2O3','Ti3O','Ti3O5','Ti6O','TiO','TiO2','Tl2O',
          'Tl2O3','Tl4O3','Tm2O3','U3O8','UO2','UO3','V2O3','V2O5','V3O5','V3O7','VO2','W18O49','WO2','WO3','Y2O3','YbO',
          'ZnO','Zr3O','ZrO2']
print('{}\t{}\t{}'.format('oxides','band','coh_energy'))
for oxide in oxides:
    band_center = BandCenter().featurize(Composition(oxide))
    coh_energy = CohesiveEnergy(mp_key).featurize(Composition(oxide))
    print('{}\t{:6.3f}\t{:6.3f}'.format(oxide, band_center[0], coh_energy[0]))
# Out:
# oxides	band	coh_energy
# Ac2O3	-2.180	 7.016
# Ag2O	-2.340	 3.167
# Ag3O4	-2.685	 3.174
# AgO	-2.577	 3.235
# As2O3	-2.866	 4.393
# As2O5	-3.020	 4.287
# Au2O3	-3.047	 3.555
# B2O3	-2.791	 6.700
# B6O	-2.198	 6.161
# BaO	-1.750	 5.088
# BaO2	-2.192	 4.540
# BeO	-2.324	 6.085
# Bi2O3	-2.780	 4.090
# Bi4O7	-2.835	 4.034
# BiO2	-2.881	 3.938
# CaO	-1.855	 5.545
# CdO	-2.411	 3.266
# Ce11O20	-2.310	 7.171
# Ce17O32	-2.331	 7.155
# Ce2O3	-2.196	 7.069
# Ce5O9	-2.304	 7.171
# Ce7O12	-2.275	 7.166
# CeO	-1.963	 6.706
# CeO2	-2.367	 7.123
# Co3O4	-2.655	 4.788
# CoO	-2.543	 4.828
# CoO2	-2.812	 4.339
# Cr2O3	-2.570	 5.549
# Cr5O12	-2.776	 4.893
# CrO2	-2.698	 5.132
# Cs11O3	-1.083	 1.989
# Cs2O	-1.290	 2.602
# Cs2O2	-1.649	 2.936
# Cs3O	-1.141	 2.190
# CsO2	-2.107	 2.976
# Cu2O	-2.316	 3.844
# Cu2O3	-2.713	 3.803
# CuO	-2.557	 4.000
# Dy2O3	-2.272	 6.807
# Er2O3	-2.287	 6.954
# Eu2O3	-2.257	 5.490
# EuO	-2.032	 5.370
# Fe2O3	-2.672	 5.162
# Fe3O4	-2.625	 5.164
# FeO	-2.509	 5.122
# Ga2O3	-2.661	 4.972
# Gd2O3	-2.257	 7.129
# GeO2	-2.876	 5.115
# HfO2	-2.487	 7.924
# HgO	-2.623	 2.285
# Ho2O3	-2.280	 6.872
# I2O5	-3.196	 2.951
# In2O3	-2.643	 4.586
# IrO2	-2.964	 5.311
# IrO3	-3.076	 4.686
# K2O	-1.322	 2.749
# K2O2	-1.680	 3.066
# KO2	-2.133	 3.026
# La2O3	-2.180	 7.246
# Li2O	-1.489	 4.027
# Li2O2	-1.836	 3.769
# Lu2O3	-2.309	 7.475
# MgO	-2.123	 5.124
# Mn2O3	-2.501	 4.760
# Mn3O4	-2.444	 4.804
# MnO	-2.309	 4.764
# MnO2	-2.637	 4.521
# Mo8O23	-3.051	 5.733
# MoO2	-2.946	 6.149
# MoO3	-3.062	 5.684
# Na2O	-1.438	 3.048
# Na2O2	-1.789	 3.159
# NaO2	-2.224	 3.007
# Nb2O5	-2.764	 7.114
# NbO	-2.346	 6.561
# NbO2	-2.665	 7.174
# Nd2O3	-2.212	 6.723
# Ni3O4	-2.673	 4.194
# NiO	-2.563	 4.457
# NpO2	-2.525	 6.922
# OsO2	-2.964	 5.824
# OsO4	-3.146	 5.267
# P2O5	-3.024	 5.299
# Pb3O4	-2.911	 3.826
# PbO	-2.831	 3.806
# PbO2	-3.021	 3.728
# PdO	-2.751	 4.048
# PdO2	-2.964	 3.776
# Pr2O3	-2.204	 6.795
# Pt3O4	-2.884	 4.838
# PtO2	-2.999	 4.625
# Pu2O3	-2.316	 6.456
# PuO2	-2.474	 6.561
# Rb2O	-1.322	 2.555
# Rb2O2	-1.680	 2.944
# Rb9O2	-1.064	 1.804
# RbO2	-2.133	 2.973
# Re2O7	-3.015	 5.860
# ReO3	-2.966	 6.117
# RhO2	-2.999	 4.893
# RuO2	-2.964	 5.458
# RuO4	-3.146	 4.637
# Sb2O3	-2.797	 4.431
# Sb2O5	-2.967	 4.413
# SbO2	-2.895	 4.509
# Sc2O3	-2.373	 7.109
# Se2O5	-3.158	 3.600
# SeO2	-3.113	 3.725
# SiO2	-2.822	 6.566
# Sm2O3	-2.235	 6.299
# Sn5O6	-2.664	 4.626
# SnO	-2.597	 4.518
# SnO2	-2.852	 4.909
# SrO	-1.808	 5.257
# SrO2	-2.240	 4.518
# Ta2O5	-2.714	 7.531
# Tb2O3	-2.180	 7.187
# Tc2O7	-3.015	 5.368
# TcO2	-2.822	 5.921
# Te2O5	-2.988	 3.922
# TeO2	-2.918	 3.977
# TeO3	-3.041	 3.862
# ThO2	-2.487	 8.192
# Ti2O	-2.013	 6.146
# Ti2O3	-2.494	 6.823
# Ti3O	-1.883	 5.865
# Ti3O5	-2.545	 6.847
# Ti6O	-1.727	 5.448
# TiO	-2.302	 6.649
# TiO2	-2.632	 6.873
# Tl2O	-2.082	 2.946
# Tl2O3	-2.545	 3.434
# Tl4O3	-2.237	 3.138
# Tm2O3	-2.295	 6.640
# U3O8	-2.681	 7.130
# UO2	-2.537	 7.364
# UO3	-2.738	 6.973
# V2O3	-2.552	 6.222
# V2O5	-2.779	 5.680
# V3O5	-2.600	 6.140
# V3O7	-2.749	 5.792
# VO2	-2.682	 5.994
# W18O49	-3.109	 6.448
# WO2	-3.034	 6.733
# WO3	-3.131	 6.364
# Y2O3	-2.272	 7.298
# YbO	-1.945	 5.752
# ZnO	-2.382	 3.776
# Zr3O	-1.687	 6.891
# ZrO2	-2.506	 7.654

# %%
df.columns
# test = Composition('AgO')
# AtomicOrbitals().featurize(test)
# BandCenter().featurize(test)
# CohesiveEnergy(mp_key).featurize(test)
# AtomicPackingEfficiency().featurize(test)
# comp = pm.Composition('Ce5O9')
# comp.oxi_state_guesses()
# Out:
# Index(['Data Dictionary', 'Oxidized Form', 'HOMO', 'LUMO', 'BC', 'OxM', 'CE',
#        'Shear', 'Bulk', 'BG', 'Hf', 'Hs', 'CNM', 'CNO', 'NNDr', 'NNDa', 'BV',
#        'ρ', 'Vol', 'PF', 'SG', 'SGT'],
#       dtype='object')

# %%
lattice = pm.Lattice.cubic(4.2)
structure = pm.Structure(lattice, ["Cs", "Cl"],[[0, 0, 0], [0.5, 0.5, 0.5]])

# %%
CoordinationNumber(structure)
# Out:
# CoordinationNumber(nn=Structure Summary
# Lattice
#     abc : 4.2 4.2 4.2
#  angles : 90.0 90.0 90.0
#  volume : 74.08800000000001
#       A : 4.2 0.0 0.0
#       B : 0.0 4.2 0.0
#       C : 0.0 0.0 4.2
# PeriodicSite: Cs (0.0000, 0.0000, 0.0000) [0.0000, 0.0000, 0.0000]
# PeriodicSite: Cl (2.1000, 2.1000, 2.1000) [0.5000, 0.5000, 0.5000],
#                    use_weights='none')
