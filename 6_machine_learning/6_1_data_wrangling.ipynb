# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('../final_metal_oxide_properties.xlsx', sheet_name='oxide_properties')

# %%
df.head()
# Out:
#    Index      Data Dictionary oxide_form   homo   lumo band_center  \
# 0    1.0            HOMO (eV)      Ac2O3 -0.338 -0.138       -2.18
# 1    2.0            LUMO (eV)       Ag2O -0.299 -0.157       -2.34
# 2    3.0          Band center      Ag3O4 -0.299 -0.299      -2.685
# 3    4.0  Cohesive energy(eV)        AgO -0.299 -0.299      -2.577
# 4    5.0      Oxidation state      As2O3 -0.338 -0.197      -2.866
#
#   cohesive_energy ox_state  shear_mod  bulk_mod  ... next_nearest_rel  \
# 0           7.016        3       35.0     103.0  ...              NaN
# 1           3.167        1        0.0      68.0  ...              NaN
# 2           3.174     2.67       22.0      87.0  ...              NaN
# 3           3.235        2       21.0      84.0  ...            0.802
# 4           4.393        3        8.0      10.0  ...              NaN
#
#   next_nearest_abs bond_valence  density  vol_per_atom  packing_factor  \
# ...

# %%
df.columns
# Out:
# Index(['Index', 'Data Dictionary', 'oxide_form', 'homo', 'lumo', 'band_center',
#        'cohesive_energy', 'ox_state', 'shear_mod', 'bulk_mod', 'band_gap',
#        'heat_formation', 'missing_ref', 'heat_sublimation', 'coord_no_metal',
#        'coord_no_oxy', 'next_nearest_rel', 'next_nearest_abs', 'bond_valence',
#        'density', 'vol_per_atom', 'packing_factor', 'sg_number', 'sg_type',
#        'crystal_system', 't_melt'],
#       dtype='object')

# %%
df.drop(columns=['Index','Data Dictionary', 'heat_sublimation', 'coord_no_metal', 'coord_no_oxy',
       'next_nearest_rel', 'next_nearest_abs', 'bond_valence','packing_factor','sg_type','crystal_system','missing_ref'],
        inplace=True)

# %%
df.tail()
# Out:
#     oxide_form   homo   lumo band_center cohesive_energy ox_state  shear_mod  \
# 149        YbO -0.286 -0.137      -1.945           5.752        2       89.0
# 150        ZnO -0.338 -0.223      -2.382           3.776        2       41.0
# 151       Zr3O -0.151 -0.151      -1.687           6.891        -       55.0
# 152       ZrO2 -0.338 -0.162      -2.506           7.654        4       85.0
# 153        NaN    NaN    NaN         NaN             NaN      NaN        NaN
#
#      bulk_mod band_gap heat_formation density vol_per_atom sg_number t_melt
# 149     128.0     3.47              -   11.72        13.39       225      -
# 150     130.0     0.73       -3.63269    5.44        12.43       186   1974
# 151     134.0        0              -     6.6      18.2225       155      -
# 152     183.0     3.47        -11.407    5.56      12.2592        14   2709
# 153       NaN      NaN            NaN     NaN          NaN       NaN    NaN

# %%
df.dropna(how='all', inplace=True)

# %%
df.head()
df.tail()
# Out:
#     oxide_form   homo   lumo band_center cohesive_energy ox_state  shear_mod  \
# 148       Y2O3 -0.338 -0.151      -2.272           7.298        3       62.0
# 149        YbO -0.286 -0.137      -1.945           5.752        2       89.0
# 150        ZnO -0.338 -0.223      -2.382           3.776        2       41.0
# 151       Zr3O -0.151 -0.151      -1.687           6.891        -       55.0
# 152       ZrO2 -0.338 -0.162      -2.506           7.654        4       85.0
#
#      bulk_mod band_gap heat_formation density vol_per_atom sg_number t_melt
# 148     138.0     4.06       -19.7471    4.89      15.3298       206   2438
# 149     128.0     3.47              -   11.72        13.39       225      -
# 150     130.0     0.73       -3.63269    5.44        12.43       186   1974
# 151     134.0        0              -     6.6      18.2225       155      -
# 152     183.0     3.47        -11.407    5.56      12.2592        14   2709

# %%
df.replace('-', np.nan, inplace=True)

# %%
df_feat = df.drop(columns=['oxide_form'])

# %%
df[df.isnull().any(axis=1)]
# Out:
#     oxide_form   homo   lumo  band_center  cohesive_energy  ox_state  \
# 2        Ag3O4 -0.299 -0.299       -2.685            3.174   2.67000
# 8          B6O -0.137 -0.137       -2.198            6.161       NaN
# 13       Bi4O7 -0.338 -0.338       -2.835            4.034   3.50000
# 14        BiO2 -0.338 -0.338       -2.881            3.938   4.00000
# 17     Ce11O20 -0.337 -0.337       -2.310            7.171   3.63600
# 18     Ce17O32 -0.337 -0.337       -2.331            7.155   3.76470
# 20       Ce5O9 -0.337 -0.337       -2.304            7.171   3.60000
# 21      Ce7O12 -0.337 -0.337       -2.275            7.166   3.42857
# 22         CeO -0.337 -0.337       -1.963            6.706   2.00000
# 26        CoO2 -0.322 -0.322       -2.812            4.339   4.00000
# 28      Cr5O12 -0.150 -0.150       -2.776            4.893   4.80000
# 29        CrO2 -0.150 -0.118       -2.698            5.132   4.00000
# 30      Cs11O3 -0.079 -0.079       -1.083            1.989       NaN
# ...

# %%
df[df['oxide_form'].str.contains('Ag')]
# Out:
#   oxide_form   homo   lumo  band_center  cohesive_energy  ox_state  shear_mod  \
# 1       Ag2O -0.299 -0.157       -2.340            3.167      1.00        0.0
# 2      Ag3O4 -0.299 -0.299       -2.685            3.174      2.67       22.0
# 3        AgO -0.299 -0.299       -2.577            3.235      2.00       21.0
#
#    bulk_mod  band_gap  heat_formation  density  vol_per_atom  sg_number  \
# 1      68.0       0.0        -0.32233     6.78     18.906667      224.0
# 2      87.0       0.0             NaN     6.55     14.027143       14.0
# 3      84.0       0.0        -0.25200     6.82     15.087500       15.0
#
#    t_melt
# 1   200.0
# 2     NaN
# 3     NaN

# %%
df.isna().sum()
# Out:
# oxide_form          0
# homo                3
# lumo                3
# band_center         3
# cohesive_energy     3
# ox_state            8
# shear_mod           0
# bulk_mod            0
# band_gap            3
# heat_formation     49
# density             3
# vol_per_atom        3
# sg_number           3
# t_melt             39
# dtype: int64
